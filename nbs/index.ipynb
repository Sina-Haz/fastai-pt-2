# %%
#| hide
from fastai_pt_2.core import *

# %% [markdown]
# # fastai-pt-2
#
# > A repository where we build up to stable diffusion from the foundations, following along with part 2 of the fastai course

# %% [markdown]
# This file will become your README and also the index of your documentation.

# %% [markdown]
# ## Developer Guide

# %% [markdown]
# If you are new to using `nbdev` here are some useful pointers to get you started.

# %% [markdown]
# ### Install fastai_pt_2 in Development mode

# %% [markdown]
# ```sh
# # make sure fastai_pt_2 package is installed in development mode
# $ pip install -e .
#
# # make changes under nbs/ directory
# # ...
#
# # compile to have changes apply to fastai_pt_2
# $ nbdev_prepare
# ```

# %% [markdown]
# ## Usage

# %% [markdown]
# ### Installation

# %% [markdown]
# Install latest from the GitHub [repository][repo]:
#
# ```sh
# $ pip install git+https://github.com/Sina-Haz/fastai-pt-2.git
# ```
#
# or from [conda][conda]
#
# ```sh
# $ conda install -c Sina-Haz fastai_pt_2
# ```
#
# or from [pypi][pypi]
#
#
# ```sh
# $ pip install fastai_pt_2
# ```
#
#
# [repo]: https://github.com/Sina-Haz/fastai-pt-2
# [docs]: https://Sina-Haz.github.io/fastai-pt-2/
# [pypi]: https://pypi.org/project/fastai-pt-2/
# [conda]: https://anaconda.org/Sina-Haz/fastai-pt-2

# %% [markdown]
# ### Documentation

# %% [markdown]
# Documentation can be found hosted on this GitHub [repository][repo]'s [pages][docs]. Additionally you can find package manager specific guidelines on [conda][conda] and [pypi][pypi] respectively.
#
# [repo]: https://github.com/Sina-Haz/fastai-pt-2
# [docs]: https://Sina-Haz.github.io/fastai-pt-2/
# [pypi]: https://pypi.org/project/fastai-pt-2/
# [conda]: https://anaconda.org/Sina-Haz/fastai-pt-2

# %% [markdown]
# ## How to use

# %% [markdown]
# Fill me in please! Don't forget code examples:

# %%
1+1
# Out:
# 2
